# %%
from lib.modules_road_sign import describe_data, preprocessing

# %%
train, test, details = describe_data('./data/roadsign')
# Out:
# Directory Read from:./data/roadsign/*
#
# Files Read:
#
# ./data/roadsign/sample_submission.csv
# ./data/roadsign/test.csv
# ./data/roadsign/train.csv

# %%
train_X, train_Y, test_X = preprocessing(train, test)
# Out:
#                                      Id DetectedCamera  AngleOfSign  \
# 0      2c9180975a056a64015a1e10d3f270fe          Right           67
# 1      2c9180975a056a64015a1de4deb16bdc          Front           16
# 2      2c9180975a056a64015a1e0e70ea70ce          Right           44
# 3      2c9180975a056a64015a1dfed0c46ec6          Right           50
# 4      2c9180975a056a64015a1dfed0c46ec7          Front           30
# 5      2c9180975a056a64015a1e44ba4377f8          Right          137
# 6      2c9180975a056a64015a1e010c8f6ee1          Front           18
# 7      2c9180975a056a64015a1e1db63072aa          Right           69
# 8      2c9180975a056a64015a1e1db63072a8           Rear          198
# 9      2c9180975a056a64015a1e2354f5733c           Rear          213
# 10     2c9180975a056a64015a1e07928f6ff8          Front           11
# 11     2c9180975a056a64015a1e20a607730a          Front           23
# 12     2c9180975a056a64015a1e3322e37587           Left          250
# ...

# %%
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DetectedCamera</th>
#       <th>AngleOfSign</th>
#       <th>SignAspectRatio</th>
#       <th>SignWidth</th>
#       <th>SignHeight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>67</td>
#       <td>0.63</td>
#       <td>107</td>
#       <td>169</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>16</td>
#       <td>0.88</td>
#       <td>61</td>
#       <td>69</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>44</td>
#       <td>1.15</td>
#       <td>232</td>
#       <td>202</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>50</td>
#       <td>1.10</td>
#       <td>137</td>
#       <td>125</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>30</td>
#       <td>0.95</td>
#       <td>99</td>
# ...
